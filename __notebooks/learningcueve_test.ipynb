# %% [markdown]
# ## Description about this notebook
# This notebook is designed to visually compare the performance of our three different YOLO NAS models (Small, Medium, Large) in terms of two key metrics: Mean Average Precision at 50% (MAP50) and Mean Average Precision from 50% to 95% (MAP50:95). We employed a supervision function for this evaluation. The assessment was carried out on a test dataset, which was not previously exposed to the models. This test dataset is unique as it comprises a new blend of Jersey and Holstein cow images, captured from two distinct camera perspectives: top and side views. This setup ensures a comprehensive evaluation of the models' ability to accurately detect and recognize objects in varied and realistic scenarios.

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import logging
#####################################
# Set logging level to WARNING to ignore INFO messages
logging.basicConfig(level=logging.WARNING)

import os
os.environ['TORCH_HOME'] = '/home/mautushid/.torch'

#from ultralytics import NAS
os.chdir("..")
ROOT = os.getcwd()
print(ROOT)
# Out:
# /home/mautushid/Cowsformer

# %%
from models.nas import *
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The console stream is logged into /home/mautushid/sg_logs/console.log
# [2024-03-04 14:28:53] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# [2024-03-04 14:28:54] WARNING - __init__.py - Failed to import pytorch_quantization
# [2024-03-04 14:29:04] WARNING - __init__.py - Matplotlib created a temporary cache directory at /localscratch/2188895/matplotlib-0_uyk3py because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# [2024-03-04 14:29:06] INFO - font_manager.py - generated new fontManager
# [2024-03-04 14:29:15] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2024-03-04 14:29:15] WARNING - export.py - Failed to import pytorch_quantization
# [2024-03-04 14:29:15] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization

# %%
# Directory containing all the checkpoints
checkpoints_dir = ROOT + "/checkpoints"

# Function to sort and organize checkpoint paths into the specified format
def organize_checkpoints_corrected(checkpoints_dir):
    # Dictionary to hold the paths categorized by category, then by type
    categorized_paths = {}

    # Iterate through each subdirectory in the checkpoints directory
    for sub_dir in os.listdir(checkpoints_dir):
        # Construct the full path of the subdirectory
        full_sub_dir_path = os.path.join(checkpoints_dir, sub_dir)
        # Check if the current path is a directory
        if os.path.isdir(full_sub_dir_path):
            # Extract category, iteration, and type from the folder name
            parts = sub_dir.split('_')
            category = parts[0] 
            category2 = parts[-1]# e.g., breed
            size_type = parts[-3][-1]  # Assuming type is represented by the last letter before the category and iteration

            # Validate size_type to be 's', 'm', or 'l'
            if size_type not in ['s', 'm', 'l']:
                continue  # Skip if size_type does not match expected values
            
            # Iterate through the RUN_... directory inside the current subdirectory
            for run_dir in os.listdir(full_sub_dir_path):
                run_dir_path = os.path.join(full_sub_dir_path, run_dir)
                if os.path.isdir(run_dir_path):
                    # Construct the path to the ckpt_best.pth file inside the RUN_... directory
                    ckpt_path = os.path.join(run_dir_path, 'ckpt_best.pth')
                    if os.path.exists(ckpt_path):
                        # Initialize the nested dictionaries and lists as needed
                        if category not in categorized_paths:
                            categorized_paths[category] = {'s': [], 'm': [], 'l': []}
                        categorized_paths[category][size_type].append(ckpt_path)

    # Sort paths within each list
    for category in categorized_paths.keys():
        for size_type in categorized_paths[category].keys():
            categorized_paths[category][size_type].sort()

    return categorized_paths

# Call the function and print the organized checkpoint paths
# Directory containing all the checkpoints
checkpoints_dir = ROOT + "/checkpoints_cow200"

# Function to sort and organize checkpoint paths into the specified format
def organize_checkpoints_corrected(checkpoints_dir):
    # Dictionary to hold the paths categorized by category, then by type
    categorized_paths = {}

    # Iterate through each subdirectory in the checkpoints directory
    for sub_dir in os.listdir(checkpoints_dir):
        # Construct the full path of the subdirectory
        full_sub_dir_path = os.path.join(checkpoints_dir, sub_dir)
        # Check if the current path is a directory
        if os.path.isdir(full_sub_dir_path):
            # Extract category, iteration, and type from the folder name
            parts = sub_dir.split('_')
            category = parts[0]  # e.g., n10
            size_type = parts[-2][-1]  # Assuming type is represented by the last letter before the category and iteration

            # Validate size_type to be 's', 'm', or 'l'
            if size_type not in ['s', 'm', 'l']:
                continue  # Skip if size_type does not match expected values
            
            # Iterate through the RUN_... directory inside the current subdirectory
            for run_dir in os.listdir(full_sub_dir_path):
                run_dir_path = os.path.join(full_sub_dir_path, run_dir)
                if os.path.isdir(run_dir_path):
                    # Construct the path to the ckpt_best.pth file inside the RUN_... directory
                    ckpt_path = os.path.join(run_dir_path, 'ckpt_best.pth')
                    if os.path.exists(ckpt_path):
                        # Initialize the nested dictionaries and lists as needed
                        if category not in categorized_paths:
                            categorized_paths[category] = {'s': [], 'm': [], 'l': []}
                        categorized_paths[category][size_type].append(ckpt_path)

    # Sort paths within each list
    for category in categorized_paths.keys():
        for size_type in categorized_paths[category].keys():
            categorized_paths[category][size_type].sort()

    return categorized_paths

# Call the function and print the organized checkpoint paths
organized_paths = organize_checkpoints_corrected(checkpoints_dir)
for category, types in organized_paths.items():
    print(f"{category}:")
    for size_type, paths in types.items():
        print(f"  {size_type}:")
        for path in paths:
            print(f"    {path}")

organized_paths = organize_checkpoints_corrected(checkpoints_dir)
for category, types in organized_paths.items():
    print(f"{category}:")
    for size_type, paths in types.items():
        print(f"  {size_type}:")
        for path in paths:
            print(f"    {path}")
# Out:
# n32:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i1_all/RUN_20240229_131134_765755/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i1_breed/RUN_20240301_021001_929576/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i1_light/RUN_20240229_125926_722225/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i1_s2t/RUN_20240229_131004_345526/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i1_t2s/RUN_20240229_144817_124821/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i2_all/RUN_20240229_230939_411706/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i2_breed/RUN_20240301_110322_862373/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i2_light/RUN_20240229_225430_498634/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i2_s2t/RUN_20240229_230933_641404/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i2_t2s/RUN_20240301_003334_269909/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i3_all/RUN_20240301_115927_206787/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i3_breed/RUN_20240301_203818_274200/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i3_light/RUN_20240301_105945_202771/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i3_s2t/RUN_20240301_115514_164056/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i3_t2s/RUN_20240301_125709_140600/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i4_breed/RUN_20240301_213112_582885/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i5_breed/RUN_20240301_213431_438171/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_s_i5_t2s/RUN_20240301_213531_018711/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i1_all/RUN_20240229_132730_546238/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i1_breed/RUN_20240301_023041_825444/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i1_light/RUN_20240229_131311_712897/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i1_s2t/RUN_20240229_132600_030012/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i1_t2s/RUN_20240229_150502_180341/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i2_all/RUN_20240229_232633_085587/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i2_breed/RUN_20240301_112411_634564/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i2_light/RUN_20240229_230957_626899/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i2_s2t/RUN_20240229_232613_632532/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i2_t2s/RUN_20240301_005155_956808/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i3_all/RUN_20240301_122620_273796/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i3_breed/RUN_20240301_210211_443972/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i3_light/RUN_20240301_112000_079264/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i3_s2t/RUN_20240301_122136_045899/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_m_i3_t2s/RUN_20240301_131510_732552/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i1_all/RUN_20240229_140400_190336/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i1_breed/RUN_20240301_031142_618785/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i1_light/RUN_20240229_134820_819146/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i1_s2t/RUN_20240229_140344_343845/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i1_t2s/RUN_20240229_154122_969689/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i2_all/RUN_20240301_000440_123257/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i2_breed/RUN_20240301_120454_900760/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i2_light/RUN_20240229_234229_189281/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i2_s2t/RUN_20240301_000431_718212/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i2_t2s/RUN_20240301_012941_217350/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i3_all/RUN_20240301_131437_869718/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i3_light/RUN_20240301_120058_397962/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i3_s2t/RUN_20240301_130823_687583/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i3_t2s/RUN_20240301_140136_279404/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n32_yolo_nas_l_i5_light/RUN_20240301_213356_936888/ckpt_best.pth
# n64:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i1_all/RUN_20240229_145020_273917/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i1_breed/RUN_20240301_041526_488029/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i1_light/RUN_20240229_143619_998539/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i1_s2t/RUN_20240229_144907_165467/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i1_t2s/RUN_20240229_162733_048056/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i2_all/RUN_20240301_005025_810954/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i2_breed/RUN_20240301_125705_471925/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i2_light/RUN_20240301_002710_536354/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i2_s2t/RUN_20240301_004904_049038/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i2_t2s/RUN_20240301_022000_986914/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i3_all/RUN_20240301_142340_287842/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i3_light/RUN_20240301_125351_860547/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i3_s2t/RUN_20240301_141328_751745/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_s_i3_t2s/RUN_20240301_150220_266826/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i1_all/RUN_20240229_150743_561497/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i1_breed/RUN_20240301_044415_934523/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i1_light/RUN_20240229_145350_047908/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i1_s2t/RUN_20240229_150735_154325/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i1_t2s/RUN_20240229_164418_717226/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i2_all/RUN_20240301_011021_921937/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i2_breed/RUN_20240301_131821_292601/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i2_light/RUN_20240301_004630_442223/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i2_s2t/RUN_20240301_010945_996160/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i2_t2s/RUN_20240301_024243_331091/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i3_all/RUN_20240301_145738_603730/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i3_light/RUN_20240301_131418_692274/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i3_s2t/RUN_20240301_144508_165736/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i3_t2s/RUN_20240301_152806_318794/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_m_i4_t2s/RUN_20240301_212911_226819/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i1_all/RUN_20240229_154751_576394/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i1_breed/RUN_20240301_052641_409932/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i1_light/RUN_20240229_153134_483621/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i1_s2t/RUN_20240229_154732_690718/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i1_t2s/RUN_20240229_172213_572433/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i2_all/RUN_20240301_015134_822773/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i2_breed/RUN_20240301_140839_063366/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i2_light/RUN_20240301_012522_574212/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i2_s2t/RUN_20240301_015121_665469/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i2_t2s/RUN_20240301_033229_541065/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i3_all/RUN_20240301_155327_988962/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i3_light/RUN_20240301_140141_678529/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i3_s2t/RUN_20240301_153637_481497/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n64_yolo_nas_l_i3_t2s/RUN_20240301_162354_610134/ckpt_best.pth
# n500:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i1_all/RUN_20240229_204137_983195/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i1_light/RUN_20240229_202151_275675/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i1_s2t/RUN_20240229_204147_717431/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i1_t2s/RUN_20240229_215527_675958/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i2_all/RUN_20240301_082248_350866/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i2_light/RUN_20240301_073513_652040/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i2_s2t/RUN_20240301_082220_073872/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i2_t2s/RUN_20240301_092624_757558/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_s_i3_light/RUN_20240301_203111_068781/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i1_all/RUN_20240229_211633_821495/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i1_light/RUN_20240229_210004_381116/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i1_s2t/RUN_20240229_211724_677688/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i1_t2s/RUN_20240229_223323_595884/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i2_all/RUN_20240301_091452_259401/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i2_light/RUN_20240301_083415_389714/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i2_s2t/RUN_20240301_091431_461131/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_m_i2_t2s/RUN_20240301_101756_529977/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i1_all/RUN_20240229_221059_725724/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i1_light/RUN_20240229_215705_187338/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i1_s2t/RUN_20240229_221144_784645/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i1_t2s/RUN_20240229_232530_058866/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i2_all/RUN_20240301_102657_079310/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i2_light/RUN_20240301_094150_958741/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i2_s2t/RUN_20240301_102632_897409/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n500_yolo_nas_l_i2_t2s/RUN_20240301_112658_507042/ckpt_best.pth
# n128:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i1_all/RUN_20240229_163813_216700/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i1_breed/RUN_20240301_062725_873139/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i1_light/RUN_20240229_162143_687107/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i1_s2t/RUN_20240229_163806_914664/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i1_t2s/RUN_20240229_181011_688878/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i2_all/RUN_20240301_024445_170853/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i2_breed/RUN_20240301_151307_647626/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i2_light/RUN_20240301_021926_874681/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i2_s2t/RUN_20240301_024554_714539/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i2_t2s/RUN_20240301_043431_810612/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i3_all/RUN_20240301_165917_631068/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i3_light/RUN_20240301_150433_309807/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i3_s2t/RUN_20240301_164410_270431/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_s_i3_t2s/RUN_20240301_172442_949120/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i1_all/RUN_20240229_170051_612826/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i1_breed/RUN_20240301_065839_972528/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i1_light/RUN_20240229_164339_474347/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i1_s2t/RUN_20240229_170030_212056/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i1_t2s/RUN_20240229_183123_516373/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i2_all/RUN_20240301_030819_759567/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i2_breed/RUN_20240301_154246_765179/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i2_light/RUN_20240301_024547_940456/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i2_s2t/RUN_20240301_030932_798381/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i2_t2s/RUN_20240301_050256_164023/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i3_all/RUN_20240301_173513_827159/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i3_light/RUN_20240301_153335_741721/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i3_s2t/RUN_20240301_171812_864374/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i3_t2s/RUN_20240301_175600_118920/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_m_i4_light/RUN_20240301_212911_594423/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i1_all/RUN_20240229_174508_119545/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i1_breed/RUN_20240301_074222_586897/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i1_light/RUN_20240229_172412_292372/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i1_s2t/RUN_20240229_174449_801330/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i1_t2s/RUN_20240229_190508_857626/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i2_all/RUN_20240301_041624_958023/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i2_breed/RUN_20240301_164050_365442/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i2_light/RUN_20240301_034049_562481/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i2_s2t/RUN_20240301_041739_465811/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i2_t2s/RUN_20240301_055252_861046/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i3_all/RUN_20240301_183313_363198/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i3_light/RUN_20240301_163124_908939/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i3_s2t/RUN_20240301_181710_273185/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n128_yolo_nas_l_i3_t2s/RUN_20240301_184809_641287/ckpt_best.pth
# n256:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i1_all/RUN_20240229_183357_580757/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i1_light/RUN_20240229_181435_908188/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i1_s2t/RUN_20240229_183328_661900/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i1_t2s/RUN_20240229_195521_761936/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i2_all/RUN_20240301_052358_104296/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i2_light/RUN_20240301_044509_250663/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i2_s2t/RUN_20240301_052456_680363/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i2_t2s/RUN_20240301_065523_265813/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i3_all/RUN_20240301_195021_358248/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i3_light/RUN_20240301_173930_191760/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i3_s2t/RUN_20240301_193229_095760/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_s_i3_t2s/RUN_20240301_195431_682378/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i1_all/RUN_20240229_185904_460420/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i1_light/RUN_20240229_184117_987755/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i1_s2t/RUN_20240229_185856_112774/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i1_t2s/RUN_20240229_202445_121952/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i2_all/RUN_20240301_060600_653035/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i2_light/RUN_20240301_052430_536729/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i2_s2t/RUN_20240301_060558_697182/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i2_t2s/RUN_20240301_073245_711269/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i3_all/RUN_20240301_203144_354098/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i3_light/RUN_20240301_181709_080863/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i3_s2t/RUN_20240301_201623_119481/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_m_i3_t2s/RUN_20240301_203537_312183/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i1_all/RUN_20240229_194610_358069/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i1_light/RUN_20240229_192718_809940/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i1_s2t/RUN_20240229_194613_504425/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i1_t2s/RUN_20240229_210305_343199/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i2_all/RUN_20240301_070915_136444/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i2_light/RUN_20240301_063101_184930/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i2_s2t/RUN_20240301_070856_437049/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i2_t2s/RUN_20240301_082747_199517/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i3_light/RUN_20240301_192055_227993/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n256_yolo_nas_l_i3_s2t/RUN_20240301_212041_317398/ckpt_best.pth
# n250:
#   s:
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_s_i1_breed/RUN_20240301_083906_073682/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_s_i2_breed/RUN_20240301_174544_777337/ckpt_best.pth
#   m:
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_m_i1_breed/RUN_20240301_091501_103507/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_m_i2_breed/RUN_20240301_182326_515530/ckpt_best.pth
#   l:
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_l_i1_breed/RUN_20240301_100403_250310/ckpt_best.pth
#     /home/mautushid/Cowsformer/checkpoints/n250_yolo_nas_l_i2_breed/RUN_20240301_192851_742402/ckpt_best.pth

# %%
n10_s_path = organized_paths['n10']['s']
n10_m_path = organized_paths['n10']['m']
n10_l_path = organized_paths['n10']['l']

n25_s_path = organized_paths['n25']['s']
n25_m_path = organized_paths['n25']['m']
n25_l_path = organized_paths['n25']['l']

n50_s_path = organized_paths['n50']['s']
n50_m_path = organized_paths['n50']['m']
n50_l_path = organized_paths['n50']['l']

n100_s_path = organized_paths['n100']['s']
n100_m_path = organized_paths['n100']['m']
n100_l_path = organized_paths['n100']['l']

n200_s_path = organized_paths['n200']['s']
n200_m_path = organized_paths['n200']['m']
n200_l_path = organized_paths['n200']['l']

# %%
print(len(n10_m_path))
print(len(n10_l_path))
# Out:
# 15
# 15

# %%
print(len(n10_s_path))
print(len(n10_m_path))
print(len(n10_l_path))

print('------------------')

print(len(n25_s_path))
print(len(n25_m_path))
print(len(n25_l_path))

print('------------------')

print(len(n50_s_path))
print(len(n50_m_path))
print(len(n50_l_path))

print('------------------')
print(len(n100_s_path))
print(len(n100_m_path))
print(len(n100_l_path))

print('------------------')
print(len(n200_s_path))
print(len(n200_m_path))
print(len(n200_l_path))

# %%
path_model_s = 'yolo_nas_s'
path_model_m = 'yolo_nas_m'
path_model_l = 'yolo_nas_l'
dir_train = "/home/mautushid/Cowsformer/data/cow200/yolov5/train"
dir_val = "/home/mautushid/Cowsformer/data/cow200/yolov5/val"
dir_test = "/home/mautushid/Cowsformer/data/cow200/yolov5/test"
name_task = "cow200"
data_yaml_path = "/home/mautushid/Cowsformer/data/cow200/yolov5/data.yaml"

def evaluate_models_s(finetuned_model_paths):
    models = []
    evaluation_results = []
    my_nas = Niche_YOLO_NAS(path_model_s, dir_train, dir_val, dir_test, name_task)
    
    # Load models
    for path in finetuned_model_paths:
        model = my_nas.load(path_model_s, path)
        models.append(model)
    
    # Evaluate models
    for model in models:
        metrics = my_nas.get_map_scores(model, data_yaml_path, "test")
        evaluation_results.append(metrics)
    
    return evaluation_results

def evaluate_models_m(finetuned_model_paths):
    models = []
    evaluation_results = []
    my_nas = Niche_YOLO_NAS(path_model_m, dir_train, dir_val, dir_test, name_task)
    
    # Load models
    for path in finetuned_model_paths:
        model = my_nas.load(path_model_m, path)
        models.append(model)
    
    # Evaluate models
    for model in models:
        metrics = my_nas.get_map_scores(model, data_yaml_path, "test")
        evaluation_results.append(metrics)
    
    return evaluation_results

def evaluate_models_l(finetuned_model_paths):
    models = []
    evaluation_results = []
    my_nas = Niche_YOLO_NAS(path_model_l, dir_train, dir_val, dir_test, name_task)
    
    # Load models
    for path in finetuned_model_paths:
        model = my_nas.load(path_model_l, path)
        models.append(model)
    
    # Evaluate models
    for model in models:
        metrics = my_nas.get_map_scores(model, data_yaml_path, "test")
        evaluation_results.append(metrics)
    
    return evaluation_results

# %%
evaluattion_results_n10_s_path = evaluate_models_s(n10_s_path)
#evaluattion_results_n10_m_path = evaluate_models_m(n10_m_path)
#evaluattion_results_n10_l_path = evaluate_models_l(n10_l_path)

# %%
evaluattion_results_n10_s_path = evaluate_models_s(n10_s_path)
evaluattion_results_n10_m_path = evaluate_models_m(n10_m_path)
evaluattion_results_n10_l_path = evaluate_models_l(n10_l_path)

evaluattion_results_n25_s_path = evaluate_models_s(n25_s_path)
evaluattion_results_n25_m_path = evaluate_models_m(n25_m_path)
evaluattion_results_n25_l_path = evaluate_models_l(n25_l_path)

evaluattion_results_n50_s_path = evaluate_models_s(n50_s_path)
evaluattion_results_n50_m_path = evaluate_models_m(n50_m_path)
evaluattion_results_n50_l_path = evaluate_models_l(n50_l_path)

evaluattion_results_n100_s_path = evaluate_models_s(n100_s_path)
evaluattion_results_n100_m_path = evaluate_models_m(n100_m_path)
evaluattion_results_n100_l_path = evaluate_models_l(n100_l_path)

evaluattion_results_n200_s_path = evaluate_models_s(n200_s_path)
evaluattion_results_n200_m_path = evaluate_models_m(n200_m_path)
evaluattion_results_n200_l_path = evaluate_models_l(n200_l_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have the actual evaluation data in these variables
# Replace these lines with your actual evaluation data
evaluation_results_n10_s_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n10_m_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n10_l_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n25_s_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n25_m_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n25_l_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n100_s_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n100_m_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n100_l_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n50_s_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n50_m_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n50_l_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n200_s_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n200_m_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]
evaluation_results_n200_l_path = [{'mAP@50': np.random.uniform(0.4, 0.8)} for _ in range(8)]



# Collect all the results in a dictionary for processing
evaluation_results = {
    'n10_s': evaluattion_results_n10_s_path,
    'n10_m': evaluattion_results_n10_m_path,
    'n10_l': evaluattion_results_n10_l_path,
    'n25_s': evaluattion_results_n25_s_path,
    'n25_m': evaluattion_results_n25_m_path,
    'n25_l': evaluattion_results_n25_l_path,
    'n50_s': evaluattion_results_n50_s_path,
    'n50_m': evaluattion_results_n50_m_path,
    'n50_l': evaluattion_results_n50_l_path,
    'n100_s': evaluattion_results_n100_s_path,
    'n100_m': evaluattion_results_n100_m_path,
    'n100_l': evaluattion_results_n100_l_path,
    'n200_s': evaluattion_results_n200_s_path,
    'n200_m': evaluattion_results_n200_m_path,
    'n200_l': evaluattion_results_n200_l_path,
    
}

# Calculate statistics for each combination of dataset size and model complexity
evaluation_statistics = {}
for key, results in evaluation_results.items():
    map50_scores = [res['mAP@50'] for res in results]
    median_map50 = np.median(map50_scores)
    q1_map50 = np.percentile(map50_scores, 25)
    q3_map50 = np.percentile(map50_scores, 75)
    
    evaluation_statistics[key] = {
        'median': median_map50,
        'q1': q1_map50,
        'q3': q3_map50
    }

# Sort the keys to make sure the data sizes are in order (from smallest to largest dataset size)
sorted_keys = sorted(evaluation_statistics, key=lambda x: (int(x[1:x.index('_')]), x[-1]))

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the median values and fill the area between Q1 and Q3
for model_size in ['s', 'm', 'l']:  # For each model size
    data_sizes = [int(key[1:key.index('_')]) for key in sorted_keys if key.endswith(model_size)]
    median_values = [evaluation_statistics[key]['median'] for key in sorted_keys if key.endswith(model_size)]
    q1_values = [evaluation_statistics[key]['q1'] for key in sorted_keys if key.endswith(model_size)]
    q3_values = [evaluation_statistics[key]['q3'] for key in sorted_keys if key.endswith(model_size)]

    # Plot the median line
    ax.plot(data_sizes, median_values, marker='o', label=f'Model {model_size.upper()} Median mAP@50')
    
    # Fill the area between Q1 and Q3 for the interquartile range
    ax.fill_between(data_sizes, q1_values, q3_values, alpha=0.2)

# Customize the plot
ax.set_title('Model performance: mAP')
ax.set_xlabel('Data Size')
ax.set_ylabel('mAP@50')
ax.set_xticks([25, 50, 75, 100, 125, 150, 175, 200]) 
ax.set_ylim(0.4, 1.0)  # Adjust y-axis limits to match your data
ax.legend(loc='upper left', frameon=True)  # Adjust legend to match the example
ax.grid(True, which='major', linestyle='--', linewidth=0.5)  # Adjust grid to be less prominent

# Show the plot
plt.show()
